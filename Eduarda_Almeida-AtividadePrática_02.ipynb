# %% [markdown]
# ##Question 1: Create List of Data Values

# %%
#creating the month list
Months = ["jan", "feb", "mar", "apr", "may", "aug", "sep", "oct", "nov", "dec"]
print(Months)
# Out:
# ['jan', 'feb', 'mar', 'apr', 'may', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
from typing_extensions import Counter
#creating the temperature list
Tc = [0.0, 2.0, 5.0, 9.56, 14.39, 21.72, 16.72, 11.61, 4.89, 0.99]
print(Tc)
# Out:
# [0.0, 2.0, 5.0, 9.56, 14.39, 21.72, 16.72, 11.61, 4.89, 0.99]

# %% [markdown]
# ##Question 2: Insert Values Into a Python List

# %%
#insert june month
Months.insert(5,"June")
print(Months)
# Out:
# ['jan', 'feb', 'mar', 'apr', 'may', 'June', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
#insert june temperature
Tc.insert(5, 19.56)
print(Tc)
# Out:
# [0.0, 2.0, 5.0, 9.56, 14.39, 19.56, 21.72, 16.72, 11.61, 4.89, 0.99]

# %%
#insert july month
Months.insert(6, "July")
print(Months)
# Out:
# ['jan', 'feb', 'mar', 'apr', 'may', 'June', 'July', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
#insert july temperature
Tc.insert(6,22.78)
print(Tc)
# Out:
# [0.0, 2.0, 5.0, 9.56, 14.39, 19.56, 22.78, 21.72, 16.72, 11.61, 4.89, 0.99]

# %% [markdown]
# ##Question 3: Manually Create Numpy Arrays

# %%
import numpy as np

# %%
Tc2 = np.array([0.0,2.0, 5.0, 9.56, 14.39, 19.56, 22.78, 21.72, 16.72, 11.61, 4.89, 0.99])
print(Tc2)
# Out:
# [ 0.    2.    5.    9.56 14.39 19.56 22.78 21.72 16.72 11.61  4.89  0.99]

# %%
Tc1 = np.array(Tc)
print(Tc1)
# Out:
# [ 0.    2.    5.    9.56 14.39 19.56 22.78 21.72 16.72 11.61  4.89  0.99]

# %% [markdown]
# ##Quesion 4: Download Text File and Import Into Numpy Arrays - erro

# %%
#creating the folder to store the data = Boulder_Tc
import requests
import numpy as np

# %%
#importando o arquivo avg-monthly-temp.txt
from urllib import request
URL = "https://ndownloader.figshare.com/files/12732467"
response = request.urlretrieve("https://ndownloader.figshare.com/files/12732467", "avg-monthly-temp.txt")
print(response)
# Out:
# ('avg-monthly-temp.txt', <http.client.HTTPMessage object at 0x7f58f2735e90>)

# %%
open ("/content/avg-monthly-temp.txt", "r")
# Out:
# <_io.TextIOWrapper name='/content/avg-monthly-temp.txt' mode='r' encoding='UTF-8'>

# %%
#abrir o arquivo avg-monthly-temp.txt (gostaria de saber o que tem dentro do arquivo)
Temp = np.array("/content/avg-monthly-temp.txt")
print(Temp)
# Out:
# /content/avg-monthly-temp.txt

# %% [markdown]
# ##Quesion 5: Select and Summarize Data From Numpy Arrays

# %%
#criar matrizes 
Matriz_1 = np.array([5.0, 9.56, 14.39])
Matriz_2 = np.array([16.72, 11.61, 4.89])
print(Matriz_1)
print(Matriz_2)
# Out:
# [ 5.    9.56 14.39]
# [16.72 11.61  4.89]

# %%
#Calcular a média de matriz 1 e matriz 1
Media_1 = np.mean(Matriz_1)
Media_2 = np.mean(Matriz_2)
print(Media_1)
print(Media_2)
# Out:
# 9.65
# 11.073333333333332

# %% [markdown]
# ##Question 6: Manually Create Pandas Dataframe

# %%
import pandas as pd

# %%
#criando o dataframe
Tc_dataframe = pd.DataFrame(columns=["Month", "Temp"], data = [["January", 0.0 ], ["February", 2.0], ["March", 5.0], ["April", 9.56], ["May", 14.39], ["June", 19.56], ["July", 22.78], ["August", 21.72], ["September", 16.72], ["October", 11.61], ["November", 4.89], ["December", 0.99]])
print(Tc_dataframe)
# Out:
#         Month   Temp
# 0     January   0.00
# 1    February   2.00
# 2       March   5.00
# 3       April   9.56
# 4         May  14.39
# 5        June  19.56
# 6        July  22.78
# 7      August  21.72
# 8   September  16.72
# 9     October  11.61
# 10   November   4.89
# 11   December   0.99

# %% [markdown]
# ##Question 7: Download CSV File and Import Into Pandas Dataframe

# %%
#Download CSV 
#importando o arquivo avg-monthly-temp.csv
URL = "https://ndownloader.figshare.com/files/12739457"
response = request.urlretrieve("https://ndownloader.figshare.com/files/12739457", "avg-temp-months-seasons.csv")
print(response)
# Out:
# ('avg-temp-months-seasons.csv', <http.client.HTTPMessage object at 0x7f58ebf435d0>)

# %%
df = pd.read_csv('avg-temp-months-seasons.csv')
print(df.to_string())
# Out:
#    months   temp seasons
# 0     Jan   0.00  Winter
# 1     Feb   2.00  Winter
# 2     Mar   5.00  Spring
# 3     Apr   9.56  Spring
# 4     May  14.39  Spring
# 5    June  19.56  Summer
# 6    July  22.78  Summer
# 7     Aug  21.72  Summer
# 8    Sept  16.72    Fall
# 9     Oct  11.61    Fall
# 10    Nov   4.89    Fall
# 11    Dec   0.99  Winter

# %%
print(df)
# Out:
#    months   temp seasons
# 0     Jan   0.00  Winter
# 1     Feb   2.00  Winter
# 2     Mar   5.00  Spring
# 3     Apr   9.56  Spring
# 4     May  14.39  Spring
# 5    June  19.56  Summer
# 6    July  22.78  Summer
# 7     Aug  21.72  Summer
# 8    Sept  16.72    Fall
# 9     Oct  11.61    Fall
# 10    Nov   4.89    Fall
# 11    Dec   0.99  Winter

# %% [markdown]
# ##Question 8: Select and Summarize Data From Pandas Dataframes

# %%
#dataframa winter (df_w)
#pulando linkas no dataframe original
df_w = pd.read_csv('avg-temp-months-seasons.csv', skiprows=[3,4,5,6,7,8,9,10,11])
print(df_w)
# Out:
#   months  temp seasons
# 0    Jan  0.00  Winter
# 1    Feb  2.00  Winter
# 2    Dec  0.99  Winter

# %%
#dataframa Spring (df_s)
df_sp = pd.read_csv('avg-temp-months-seasons.csv', skiprows=[1,2,6,7,8,9,10,11,12])
print(df_sp)
# Out:
#   months   temp seasons
# 0    Mar   5.00  Spring
# 1    Apr   9.56  Spring
# 2    May  14.39  Spring

# %%
#dataframa Summer (df_s)
df_sm = pd.read_csv('avg-temp-months-seasons.csv', skiprows=[1,2,3,4,5,9,10,11,12])
print(df_sm)
# Out:
#   months   temp seasons
# 0   June  19.56  Summer
# 1   July  22.78  Summer
# 2    Aug  21.72  Summer

# %%
#Utilizando o metodo df.describe para obter parametros estastiticos(https://www.delftstack.com/pt/howto/python-pandas/how-to-get-average-of-a-column-of-a-pandas-dataframe/) 
#winter
df_w = pd.DataFrame(df_w)
print(df_w.describe())
# Out:
#            temp
# count  3.000000
# mean   0.996667
# std    1.000017
# min    0.000000
# 25%    0.495000
# 50%    0.990000
# 75%    1.495000
# max    2.000000

# %%
#spring
df_sp = pd.DataFrame(df_sp)
print(df_sp.describe())
# Out:
#             temp
# count   3.000000
# mean    9.650000
# std     4.695647
# min     5.000000
# 25%     7.280000
# 50%     9.560000
# 75%    11.975000
# max    14.390000

# %%
#summer
df_sm = pd.DataFrame(df_sm)
print(df_sm.describe())
# Out:
#             temp
# count   3.000000
# mean   21.353333
# std     1.641016
# min    19.560000
# 25%    20.640000
# 50%    21.720000
# 75%    22.250000
# max    22.780000

# %%
#criando o dataframe Medias
Mean_df = pd.DataFrame(columns=["Season", "Mean"], data = [["Winter", 0.99 ], ["Spring", 9.65], ["Summer", 21.35]])
print(Mean_df)
# Out:
#    Season   Mean
# 0  Winter   0.99
# 1  Spring   9.65
# 2  Summer  21.35

# %% [markdown]
# ##Question 9: Plot Data From Pandas Dataframes

# %%
#importando pacotes
import matplotlib

# %%
#Plot Data From  Dataframes Mean_df
Mean_df.plot(x ='Season', y='Mean', kind = 'bar', color = "red", title = "Mean of seasons")

# %% [markdown]
# ##Question 10: Calculate the mean temperature manually

# %%
#consultar valores de temperatura em avg-temp-months-seasons.csv
print(df)
# Out:
#    months   temp seasons
# 0     Jan   0.00  Winter
# 1     Feb   2.00  Winter
# 2     Mar   5.00  Spring
# 3     Apr   9.56  Spring
# 4     May  14.39  Spring
# 5    June  19.56  Summer
# 6    July  22.78  Summer
# 7     Aug  21.72  Summer
# 8    Sept  16.72    Fall
# 9     Oct  11.61    Fall
# 10    Nov   4.89    Fall
# 11    Dec   0.99  Winter

# %%
#criar lista np.array
Temp = np.array([0.0,2.0,5.0,9.56,14.39,19.56,22.78,21.72,16.72,11.61,4.89,0.99])
Temp
# Out:
# array([ 0.  ,  2.  ,  5.  ,  9.56, 14.39, 19.56, 22.78, 21.72, 16.72,
#        11.61,  4.89,  0.99])

# %%
for array in Temp:
    array_median = np.median(array)
    print("median =", array_median)
# Out:
# median = 0.0
# median = 2.0
# median = 5.0
# median = 9.56
# median = 14.39
# median = 19.56
# median = 22.78
# median = 21.72
# median = 16.72
# median = 11.61
# median = 4.89
# median = 0.99

# %% [markdown]
# #Question 11: Calculate the mean temperature manually of each season

# %%
#summer
df_sm
# Out:
#   months   temp seasons
# 0   June  19.56  Summer
# 1   July  22.78  Summer
# 2    Aug  21.72  Summer

# %%
#winter
df_w
# Out:
#   months  temp seasons
# 0    Jan  0.00  Winter
# 1    Feb  2.00  Winter
# 2    Dec  0.99  Winter

# %%
#spring
df_sp
# Out:
#   months   temp seasons
# 0    Mar   5.00  Spring
# 1    Apr   9.56  Spring
# 2    May  14.39  Spring

# %%
#calcular média de cada lista com o for
all_season = [df_sm, df_w, df_sp]
for season in all_season:
    season_median = season['temp'].mean()
    print(season_median)
# Out:
# 21.353333333333335
# 0.9966666666666667
# 9.65

# %%
#metodo robusto
seasons = ['Winter', 'Spring','Summer']
for ii in seasons:
    season_median = df['temp'][df['seasons']==ii].mean()
    print(season_median)
# Out:
# 0.9966666666666667
# 9.65
# 21.353333333333335

# %%
df['temp'][df['seasons']=='Winter']
# Out:
# 0     0.00
# 1     2.00
# 11    0.99
# Name: temp, dtype: float64

# %%
#metodo + robusto
for ii in set(df['seasons']):
    season_median = df['temp'][df['seasons']==ii].mean()
    print(season_median)
# Out:
# 21.353333333333335
# 9.65
# 11.073333333333332
# 0.9966666666666667

# %% [markdown]
# #Get Data

# %%
import os
import urllib.request
import pandas as pd
import numpy as np
# print message after packages imported successfully
print("import of packages successful")
# Out:
# import of packages successful

# %%
#configurando o diretorio Data
os.mkdir("data")

# %%
#download dos arquivos
urllib.request.urlretrieve(url = "https://ndownloader.figshare.com/files/12807380",
                           filename = "data/monthly-precip-1988-to-1992.csv")
urllib.request.urlretrieve(url = "https://ndownloader.figshare.com/files/12807383",
                           filename = "data/monthly-precip-1993-to-1997.csv")
# Out:
# ('data/monthly-precip-1993-to-1997.csv',
#  <http.client.HTTPMessage at 0x7f58ebf68990>)

# %%
#importando como np.array
from numpy import genfromtxt
precip_1988a1992 = np.genfromtxt("data/monthly-precip-1988-to-1992.csv", delimiter=',')
precip_1993a1997 = np.genfromtxt("data/monthly-precip-1993-to-1997.csv", delimiter=',')
print(precip_1988a1992)


print(precip_1993a1997)
# Out:
# [[0.4  1.14 2.53 1.48 3.7  0.7  0.71 1.33 2.02 0.03 0.75 2.16]
#  [1.19 1.27 0.97 1.95 2.68 2.93 1.43 1.63 3.54 1.4  0.09 1.54]
#  [1.04 1.32 4.55 2.16 1.73 0.39 4.23 1.13 1.84 0.96 1.6  0.75]
#  [1.05 0.15 0.43 2.41 2.9  3.59 3.11 2.08 1.21 0.93 3.3  0.01]
#  [0.67 0.   5.17 0.46 1.7  0.96 1.13 3.08 0.02 0.79 2.56 0.84]]
# [[0.25 0.9  2.15 2.56 1.73 3.38 1.4  1.04 3.32 2.42 2.17 0.55]
#  [0.86 1.37 1.61 3.46 1.35 0.93 0.35 2.56 0.54 1.02 2.25 0.49]
#  [0.64 1.53 1.21 5.45 9.59 4.03 0.72 1.45 2.96 0.59 1.51 0.25]
#  [1.89 0.29 2.16 1.49 4.63 2.77 1.96 0.63 3.48 0.28 1.43 0.37]
#  [0.87 1.83 0.91 5.77 2.19 3.69 1.14 5.27 1.92 2.7  1.52 0.68]]

# %%
#download dos arquivos
urllib.request.urlretrieve(url = "https://ndownloader.figshare.com/files/12807389",
                           filename = "data/temp-1991-to-1995-months.csv")
urllib.request.urlretrieve(url = "https://ndownloader.figshare.com/files/12807386",
                           filename = "data/temp-1996-to-2000-months.csv")
# Out:
# ('data/temp-1996-to-2000-months.csv',
#  <http.client.HTTPMessage at 0x7f58ebf6da50>)

# %%
import pandas as pd
temp1991a1995 = pd.read_csv('data/temp-1991-to-1995-months.csv')
temp1996a2000 = pd.read_csv('data/temp-1996-to-2000-months.csv')
temp1991a1995
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1991     29.9      40.9   42.8   47.8  58.2  66.6  70.5    69.2       61.7
# 1  1992     35.9      40.6   43.3   54.3  59.1  62.9  68.3    66.3       64.4
# 2  1993     28.3      30.6   42.4   47.6  57.5  64.5  69.5    67.3       58.8
# 3  1994     35.5      31.9   43.9   47.6  60.8  70.0  71.2    70.9       65.0
# 4  1995     34.5      38.3   42.1   45.1  50.9  62.4  70.5    74.0       60.4
#
#    October  November  December
# 0     52.1      36.8      35.3
# 1     54.1      34.1      29.2
# 2     48.7      35.6      35.4
# 3     50.6      36.6      36.1
# 4     50.5      45.0      36.3

# %%
temp1996a2000
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1996     29.7      37.7   37.9   50.4  58.9  66.9  71.5    69.5       60.8
# 1  1997     31.3      32.8   45.5   42.8  57.4  66.5  71.4    68.7       64.0
# 2  1998     36.5      36.4   38.7   46.5  58.8  62.1  72.8    70.7       67.1
# 3  1999     36.4      42.1   46.0   44.5  55.6  64.8  73.5    69.3       58.5
# 4  2000     36.4      41.0   42.9   51.2  61.0  67.4  74.7    73.0       63.1
#
#    October  November  December
# 0     53.1      40.6      36.5
# 1     52.7      37.9      33.9
# 2     50.4      44.0      32.2
# 3     51.9      48.0      36.9
# 4     49.6      31.4      31.2

# %% [markdown]
# #Question 12: Use Indexing to Select from Numpy Array

# %%
precip_1988a1992_second_row = precip_1988a1992[1:2,0:12]
precip_1988a1992_second_row
# Out:
# array([[1.19, 1.27, 0.97, 1.95, 2.68, 2.93, 1.43, 1.63, 3.54, 1.4 , 0.09,
#         1.54]])

# %% [markdown]
# #Question 13: Write a Conditional Statement to Check Dimensions of Numpy Array erro

# %%
if precip_1988a1992_second_row.shape ==(1,12):
    print("o array é  unidimenssional")
else:
    print('o array  é não unidimenssional')
# Out:
# o array é  unidimenssional

# %% [markdown]
# #Question 14: Expand Conditional Statement to Execute Different Code

# %%
if precip_1988a1992_second_row.shape ==(1,12):
    print(precip_1988a1992_second_row.shape)
else:
    arrayname_1d = precip_1988a1992_second_row.flatten()
    print(arrayname_1d.shape)
# Out:
# (1, 12)

# %% [markdown]
# #Question 15: Write a Conditional Statement to Check Dimensions of Two Numpy Arrays

# %%
#criando um array com uma dimensão 
meses = np.array([['jan', 'fev', 'mar', 'abr', 'mai','jun', 'jul', 'ago', 'set','out', 'nov', 'dez']])
meses
# Out:
# array([['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set',
#         'out', 'nov', 'dez']], dtype='<U3')

# %%
meses.shape
# Out:
# (1, 12)

# %%
if precip_1988a1992_second_row.shape == meses.shape:
  print('os arrays possuem a mesma dimensão e podem ser plotados juntos')
else:
  print('os arrays não possuem a mesma dimensãoe e não podem ser plotados juntos')
# Out:
# os arrays possuem a mesma dimensão e podem ser plotados juntos

# %% [markdown]
# #Question 16: Loop on Pandas Dataframes

# %%
#pandas dataframe 
temp1991a1995
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1991     29.9      40.9   42.8   47.8  58.2  66.6  70.5    69.2       61.7
# 1  1992     35.9      40.6   43.3   54.3  59.1  62.9  68.3    66.3       64.4
# 2  1993     28.3      30.6   42.4   47.6  57.5  64.5  69.5    67.3       58.8
# 3  1994     35.5      31.9   43.9   47.6  60.8  70.0  71.2    70.9       65.0
# 4  1995     34.5      38.3   42.1   45.1  50.9  62.4  70.5    74.0       60.4
#
#    October  November  December
# 0     52.1      36.8      35.3
# 1     54.1      34.1      29.2
# 2     48.7      35.6      35.4
# 3     50.6      36.6      36.1
# 4     50.5      45.0      36.3

# %%
#pandas dataframe 
temp1996a2000
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1996     29.7      37.7   37.9   50.4  58.9  66.9  71.5    69.5       60.8
# 1  1997     31.3      32.8   45.5   42.8  57.4  66.5  71.4    68.7       64.0
# 2  1998     36.5      36.4   38.7   46.5  58.8  62.1  72.8    70.7       67.1
# 3  1999     36.4      42.1   46.0   44.5  55.6  64.8  73.5    69.3       58.5
# 4  2000     36.4      41.0   42.9   51.2  61.0  67.4  74.7    73.0       63.1
#
#    October  November  December
# 0     53.1      40.6      36.5
# 1     52.7      37.9      33.9
# 2     50.4      44.0      32.2
# 3     51.9      48.0      36.9
# 4     49.6      31.4      31.2

# %%
dataframe_list = [temp1991a1995,temp1996a2000]
dataframe_list
# Out:
# [   Year  January  February  March  April   May  June  July  August  September  \
#  0  1991     29.9      40.9   42.8   47.8  58.2  66.6  70.5    69.2       61.7
#  1  1992     35.9      40.6   43.3   54.3  59.1  62.9  68.3    66.3       64.4
#  2  1993     28.3      30.6   42.4   47.6  57.5  64.5  69.5    67.3       58.8
#  3  1994     35.5      31.9   43.9   47.6  60.8  70.0  71.2    70.9       65.0
#  4  1995     34.5      38.3   42.1   45.1  50.9  62.4  70.5    74.0       60.4
#
#     October  November  December
#  0     52.1      36.8      35.3
#  1     54.1      34.1      29.2
#  2     48.7      35.6      35.4
#  3     50.6      36.6      36.1
#  4     50.5      45.0      36.3  ,
#     Year  January  February  March  April   May  June  July  August  September  \
#  0  1996     29.7      37.7   37.9   50.4  58.9  66.9  71.5    69.5       60.8
#  1  1997     31.3      32.8   45.5   42.8  57.4  66.5  71.4    68.7       64.0
# ...

# %%
for item in dataframe_list:
    item.info()
    print(item)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       5 non-null      int64
#  1   January    5 non-null      float64
#  2   February   5 non-null      float64
#  3   March      5 non-null      float64
#  4   April      5 non-null      float64
#  5   May        5 non-null      float64
#  6   June       5 non-null      float64
#  7   July       5 non-null      float64
#  8   August     5 non-null      float64
#  9   September  5 non-null      float64
#  10  October    5 non-null      float64
#  11  November   5 non-null      float64
#  12  December   5 non-null      float64
# dtypes: float64(12), int64(1)
# memory usage: 648.0 bytes
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1991     29.9      40.9   42.8   47.8  58.2  66.6  70.5    69.2       61.7
# ...

# %% [markdown]
# #Question 17: Loop on Columns in Pandas Dataframes

# %%
#teste
temp1996a2000[['January']]
# Out:
#    January
# 0     29.7
# 1     31.3
# 2     36.5
# 3     36.4
# 4     36.4

# %%
lista_valores = [temp1996a2000[['January']],temp1996a2000[['February']], temp1996a2000[['March']], temp1996a2000[['April']], temp1996a2000[['May']], temp1996a2000[['June']], temp1996a2000[['July']], temp1996a2000[['August']], temp1996a2000[['September']], temp1996a2000[['October']], temp1996a2000[['November']], temp1996a2000[['December']]]
lista_valores
# Out:
# [   January
#  0     29.7
#  1     31.3
#  2     36.5
#  3     36.4
#  4     36.4,    February
#  0      37.7
#  1      32.8
#  2      36.4
#  3      42.1
#  4      41.0,    March
#  0   37.9
#  1   45.5
#  2   38.7
#  3   46.0
#  4   42.9,    April
#  0   50.4
#  1   42.8
#  2   46.5
#  3   44.5
#  4   51.2,     May
#  0  58.9
#  1  57.4
#  2  58.8
#  3  55.6
#  4  61.0,    June
#  0  66.9
#  1  66.5
#  2  62.1
#  3  64.8
#  4  67.4,    July
#  0  71.5
#  1  71.4
#  2  72.8
#  3  73.5
#  4  74.7,    August
#  0    69.5
#  1    68.7
#  2    70.7
#  3    69.3
#  4    73.0,    September
#  0       60.8
#  1       64.0
#  2       67.1
#  3       58.5
#  4       63.1,    October
#  0     53.1
#  1     52.7
#  2     50.4
#  3     51.9
#  4     49.6,    November
#  0      40.6
#  1      37.9
#  2      44.0
#  3      48.0
#  4      31.4,    December
#  0      36.5
#  1      33.9
#  2      32.2
#  3      36.9
#  4      31.2]

# %%
for banana in lista_valores:
    descricao = banana.describe()
    print(descricao)
# Out:
#          January
# count   5.000000
# mean   34.060000
# std     3.298939
# min    29.700000
# 25%    31.300000
# 50%    36.400000
# 75%    36.400000
# max    36.500000
#         February
# count   5.000000
# mean   38.000000
# std     3.724916
# min    32.800000
# 25%    36.400000
# 50%    37.700000
# 75%    41.000000
# max    42.100000
#            March
# count   5.000000
# mean   42.200000
# std     3.760319
# min    37.900000
# 25%    38.700000
# 50%    42.900000
# 75%    45.500000
# max    46.000000
#            April
# count   5.000000
# mean   47.080000
# std     3.650616
# min    42.800000
# 25%    44.500000
# 50%    46.500000
# 75%    50.400000
# max    51.200000
#            May
# count   5.0000
# mean   58.3400
# std     1.9995
# min    55.6000
# 25%    57.4000
# 50%    58.8000
# 75%    58.9000
# max    61.0000
#             June
# count   5.000000
# mean   65.540000
# std     2.157081
# min    62.100000
# 25%    64.800000
# 50%    66.500000
# 75%    66.900000
# ...

# %% [markdown]
# #Question 18: Write Function to Summarize Numpy Array Using Axes

# %%
#numpy array
print(precip_1993a1997)
# Out:
# [[0.25 0.9  2.15 2.56 1.73 3.38 1.4  1.04 3.32 2.42 2.17 0.55]
#  [0.86 1.37 1.61 3.46 1.35 0.93 0.35 2.56 0.54 1.02 2.25 0.49]
#  [0.64 1.53 1.21 5.45 9.59 4.03 0.72 1.45 2.96 0.59 1.51 0.25]
#  [1.89 0.29 2.16 1.49 4.63 2.77 1.96 0.63 3.48 0.28 1.43 0.37]
#  [0.87 1.83 0.91 5.77 2.19 3.69 1.14 5.27 1.92 2.7  1.52 0.68]]

# %% [markdown]
# #Question 19: Execute Function and Save Output to New Numpy Array

# %%
def ambos(array):
  linhas = np.mean(array, axis = 1)
  colunas = np.mean(array, axis = 0)
  return (linhas, colunas)

ambos(temp1996a2000)
# Out:
# (0    200.730769
#  1    200.146154
#  2    201.092308
#  3    202.038462
#  4    201.761538
#  dtype: float64, Year         1998.00
#  January        34.06
#  February       38.00
#  March          42.20
#  April          47.08
#  May            58.34
#  June           65.54
#  July           72.78
#  August         70.24
#  September      62.70
#  October        51.54
#  November       40.38
#  December       34.14
#  dtype: float64)

# %%
def ambos(array):
  linhas = np.mean(array, axis = 1)
  colunas = np.mean(array, axis = 0)
  return (linhas, colunas)

ambos(precip_1993a1997)
# Out:
# (array([1.8225    , 1.39916667, 2.49416667, 1.78166667, 2.37416667]),
#  array([0.902, 1.184, 1.608, 3.746, 3.898, 2.96 , 1.114, 2.19 , 2.444,
#         1.402, 1.776, 0.468]))
